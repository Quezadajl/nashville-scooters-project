# %%
from shapely.geometry import Point # Use in geospatial environment
import pandas as pd
import geopandas as gpd # Use in geospatial environment
import matplotlib.pyplot as plt
import folium #Use in geospatial environment
from folium import plugins
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37203       33  NASHVILLE  93532.890729543782  120334624.37817383
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
# 4  37246       57  NASHVILLE  2247.4521491892065  315078.17651367187
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.78734 36.16688, -86.78711 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...
# 4  MULTIPOLYGON (((-86.79052 36.15846, -86.79107 ...

# %%
type(zipcodes)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
zipcodes.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   zip             57 non-null     object
#  1   objectid        57 non-null     object
#  2   po_name         57 non-null     object
#  3   shape_stlength  57 non-null     object
#  4   shape_starea    57 non-null     object
#  5   geometry        57 non-null     geometry
# dtypes: geometry(1), object(5)
# memory usage: 2.8+ KB

# %%
zipcodes.loc[0,'geometry']

# %%
zipcodes.plot();

# %%
#geopandas handles legend styling if you pass a dict of keywords

leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 3}

zipcodes.plot(column = 'zip', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set3')
plt.show()

# %%
may_trips_pkl = pd.read_pickle('../data/may_trips.pkl')
print(may_trips_pkl.shape)
may_trips_pkl.head()
# Out:
# (224969, 10)
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
# 3 2019-05-01 00:05:55.570       BRD2166
# 4 2019-05-01 00:05:55.570       BRD2165
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
# 3  [[36.149741,-86.779344],[36.149741,-86.779327]...   PoweredZIIVX
# 4  [[36.177699,-86.786477],[36.177711,-86.786469]...   PoweredJ7MB3
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
# 3        3.0000    1200.78744       36.14940     36.15310       -86.77950
# 4        2.0000     351.04988       36.17780     36.17740       -86.78660
#
#    endLongitude
# 0     -86.80670
# 1     -86.77689
# 2     -86.78680
# 3     -86.77960
# 4     -86.78760

# %%
may_trips_pkl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224969 entries, 0 to 224968
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    224969 non-null  datetime64[ns]
#  1   tripRecordNum   224969 non-null  object
#  2   tripRoute       224969 non-null  object
#  3   sumdID          224969 non-null  object
#  4   tripDuration    224969 non-null  float64
#  5   tripDistance    224969 non-null  float64
#  6   startLatitude   224969 non-null  float64
#  7   endLatitude     224969 non-null  float64
#  8   startLongitude  224969 non-null  float64
#  9   endLongitude    224969 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 17.2+ MB

# %%
may_trips_pkl.loc[0].startLatitude
# Out:
# 36.1571

# %%
may_trips_pkl['geometry'] = may_trips_pkl.apply(lambda x: Point((x.startLongitude, x.startLatitude)), 
                                        axis=1)
may_trips_pkl.head(3)
# Out:
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
#
#    endLongitude                    geometry
# 0     -86.80670    POINT (-86.8036 36.1571)
# 1     -86.77689  POINT (-86.77896 36.15797)
# 2     -86.78680    POINT (-86.7818 36.1547)

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
may_scooter_geo = gpd.GeoDataFrame(may_trips_pkl, 
                           crs = zipcodes.crs, 
                           geometry = may_trips_pkl['geometry'])

# %%
type(may_trips_pkl)
# Out:
# pandas.core.frame.DataFrame

# %%
type(may_scooter_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
may_scooter_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 224969 entries, 0 to 224968
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    224969 non-null  datetime64[ns]
#  1   tripRecordNum   224969 non-null  object
#  2   tripRoute       224969 non-null  object
#  3   sumdID          224969 non-null  object
#  4   tripDuration    224969 non-null  float64
#  5   tripDistance    224969 non-null  float64
#  6   startLatitude   224969 non-null  float64
#  7   endLatitude     224969 non-null  float64
#  8   startLongitude  224969 non-null  float64
#  9   endLongitude    224969 non-null  float64
#  10  geometry        224969 non-null  geometry
# dtypes: datetime64[ns](1), float64(6), geometry(1), object(3)
# memory usage: 18.9+ MB

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
stops_by_zip = gpd.sjoin(may_scooter_geo, zipcodes, op = 'within')

# %%
stops_by_zip.head()
# Out:
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
# 3 2019-05-01 00:05:55.570       BRD2166
# 5 2019-05-01 00:05:55.570       BRD2167
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
# 3  [[36.149741,-86.779344],[36.149741,-86.779327]...   PoweredZIIVX
# 5  [[36.154368,-86.785909],[36.151689,-86.784331]...   PoweredEJF1K
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
# 3        3.0000    1200.78744       36.14940     36.15310       -86.77950
# 5        3.0000     984.25200       36.15440     36.15150       -86.78620
#
#    endLongitude                    geometry  index_right    zip    po_name
# 0     -86.80670  POINT (-86.80360 36.15710)            1  37203  NASHVILLE
# 1     -86.77689  POINT (-86.77896 36.15797)            1  37203  NASHVILLE
# 2     -86.78680  POINT (-86.78180 36.15470)            1  37203  NASHVILLE
# 3     -86.77960  POINT (-86.77950 36.14940)            1  37203  NASHVILLE
# 5     -86.78440  POINT (-86.78620 36.15440)            1  37203  NASHVILLE

# %%
stops_by_zip['zip'].value_counts()
# Out:
# 37203    97397
# 37201    39847
# 37219    17858
# 37212    17020
# 37204    15713
# 37206     8866
# 37208     8725
# 37213     8710
# 37210     4870
# 37240     1605
# 37232     1379
# 37207     1086
# 37209      702
# 37215      330
# 37228      243
# 37216      206
# 37205      185
# 37246       99
# 37211       42
# 37217       41
# 37214       15
# 37013       15
# 37218        5
# 37221        5
# 37115        3
# 37138        1
# 37220        1
# Name: zip, dtype: int64

# %%
stops_in_37013 = stops_by_zip.loc[stops_by_zip['zip'] == '37013']
stops_in_37013.shape
# Out:
# (15, 14)

# %%
polygon37013 = zipcodes.loc[zipcodes['zip'] == '37013']
polygon37013.shape
# Out:
# (1, 3)

# %%
#fig, ax = matplotlib.subplots()
ax = polygon37013.plot(figsize = (8, 10), color = 'lightgreen')
stops_in_37013.plot( ax = ax, column = 'sumdID');
plt.show();

# %%
polygon37013.geometry.centroid
# Out:
# C:\Users\Joselit\AppData\Local\Temp/ipykernel_8476/3672746340.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon37013.geometry.centroid
# 47    POINT (-86.63636 36.04177)
# dtype: geometry

# %%
#find the center of the larger (more southern) polygon and look at it
center = polygon37013.geometry.centroid[47]
print(center)
# Out:
# POINT (-86.63635924054334 36.04176675016872)
# C:\Users\Joselit\AppData\Local\Temp/ipykernel_8476/2910639564.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = polygon37013.geometry.centroid[47]

# %%
# reverse the order when constructing the array for folium location
area_center = [center.y, center.x]

# check the order of area_center, the location for our folium map
print(area_center)
# Out:
# [36.04176675016872, -86.63635924054334]

# %%
#create our map of Nashville Zip Code 37013 and show it
map_37013 = folium.Map(location =  area_center, zoom_start = 12)
map_37013
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_273e90a5b0a64f16bd7649e0b718691d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_273e90a5b0a64f16bd7649e0b718691d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_273e90a5b0a64f16bd7649e0b718691d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_273e90a5b0a64f16bd7649e0b718691d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.04176675016872%2C%20-86.63635924054334%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
i = 0
for row_index, row_values in stops_in_37013.iterrows():
    if i <3: 
        print('index is', row_index)
        print('values are:')
        print(' ')
        print(row_values)
        print('------------------------- ')
        i+=1
# Out:
# index is 40866
# values are:
#
# pubTimeStamp                             2019-05-06 23:08:57.217000
# tripRecordNum                                               LIM3008
# tripRoute         [[36.06509,-86.61038],[36.06512,-86.61045],[36...
# sumdID                                         PoweredGN6ZPQ2TW5MVA
# tripDuration                                               1.516667
# tripDistance                                                 8.8392
# startLatitude                                             36.065018
# endLatitude                                               36.065065
# startLongitude                                            -86.61029
# endLongitude                                             -86.610261
# geometry                       POINT (-86.61029000000001 36.065018)
# index_right                                                      47
# zip                                                           37013
# po_name                                                     ANTIOCH
# Name: 40866, dtype: object
# -------------------------
# index is 47022
# values are:
#
# pubTimeStamp                             2019-05-07 23:50:45.293000
# tripRecordNum                                               LIM2843
# tripRoute         [[36.06513,-86.61034],[36.06512,-86.61036],[36...
# sumdID                                         PoweredGN6ZPQ2TW5MVA
# tripDuration                                              39.333333
# tripDistance                                               875.3856
# startLatitude                                             36.065059
# endLatitude                                               36.065162
# startLongitude                                           -86.610257
# endLongitude                                              -86.61043
# geometry                               POINT (-86.610257 36.065059)
# index_right                                                      47
# zip                                                           37013
# po_name                                                     ANTIOCH
# Name: 47022, dtype: object
# -------------------------
# index is 65388
# values are:
#
# pubTimeStamp                             2019-05-11 15:57:01.613000
# tripRecordNum                                               LIM1086
# tripRoute         [[36.06274,-86.62752],[36.06274,-86.62752],[36...
# sumdID                                         PoweredVUJAJ6H4VVDJF
# tripDuration                                                   10.9
# tripDistance                                               101.8032
# startLatitude                                             36.062873
# endLatitude                                               36.062659
# startLongitude                                           -86.627801
# endLongitude                                             -86.627895
# geometry                       POINT (-86.62780100000001 36.062873)
# index_right                                                      47
# zip                                                           37013
# po_name                                                     ANTIOCH
# Name: 65388, dtype: object
# -------------------------

# %%
#draw our zip code area: 37013
map_37013 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37013).add_to(map_37013)

#iterate through stops_in_37013 to create locations and markers 
#for each bus stop
#remember for Folium locations, lat is listed first!!

for row_index, row_values in stops_in_37013.iterrows():
    loc = [row_values['startLatitude'], row_values['startLongitude']]
    pop = str(row_values['sumdID'])
    icon=folium.Icon(color="blue",icon="bicycle", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop, icon = icon) 

    marker.add_to(map_37013)
#map_37215.save('../maps/map37215.html')

#display our map
map_37013
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_89dd2e9e7e8e408291fafd89f848dbf3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_89dd2e9e7e8e408291fafd89f848dbf3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_89dd2e9e7e8e408291fafd89f848dbf3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_89dd2e9e7e8e408291fafd89f848dbf3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.04176675016872%2C%20-86.63635924054334%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
folium.Map?

# %%
cluster_map_37013 = folium.Map(location =  area_center, zoom_start = 12)

#create a marker cluster
marker_cluster = MarkerCluster().add_to(cluster_map_37013)

folium.GeoJson(polygon37013).add_to(cluster_map_37013)

# inside the loop add each marker to the cluster
for row_index, row_values in stops_in_37013.iterrows():
    loc = [row_values['startLatitude'], row_values['startLongitude']]
    pop = str(row_values['tripRoute'])
    icon=folium.Icon(color="blue",icon="bicyle", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop,
    icon = icon) 
    
    marker.add_to(marker_cluster)

    
#save an interactive HTML map by calling .save()
#cluster_map_37215.save('../maps/cluster37215.html')

cluster_map_37013
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_57e347adfea34ea2bccceeea23665638%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_57e347adfea34ea2bccceeea23665638%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A ...

# %%
#draw our zip code area: 37215
map_37013 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37013).add_to(map_37013)

#create a list of locations and pass them to FastMarkerCluster()
locations = stops_in_37013[['startLatitude', 'startLongitude']].values.tolist()
map_37013.add_child(
    FastMarkerCluster(locations)
)



#display our map
map_37215
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7536db8e7a69450197dfe41cd1cfa845%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7536db8e7a69450197dfe41cd1cfa845%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7536db8e7a69450197dfe41cd1cfa845%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7536db8e7a69450197dfe41cd1cfa845%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.04176675016872%2C%20-86.63635924054334%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...
