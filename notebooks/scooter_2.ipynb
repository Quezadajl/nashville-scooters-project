# %%
import pandas as pd
import pickle

# %% [markdown]
# #Reading in my pickles

# %%
june = pd.read_pickle('../data/june.pkl')
june.head()
# Out:
#               pubdatetime  latitude  longitude  \
# 0 2019-05-01 00:01:41.247   36.1202   -86.7534
# 1 2019-05-01 00:01:41.247   36.1630   -86.7765
# 2 2019-05-01 00:01:41.247   36.1202   -86.7533
# 3 2019-05-01 00:01:41.247   36.1201   -86.7530
# 4 2019-05-01 00:01:41.247   36.1622   -86.7806
#
#                                         sumdid  chargelevel companyname
# 0  Powered93627c35-0f62-5b81-a78d-75a4a92ecf47         90.0        Jump
# 1  Powered17715097-e8a0-5494-a5ab-9b625796607d         63.0        Jump
# 2  Powerede5cb95ae-b091-5a93-86fa-ededd946d0d7         77.0        Jump
# 3  Powered71fa5e4f-1e17-54c4-936d-330df38cc2fa          0.0        Jump
# 4  Poweredfa549dd6-40bb-5757-ac87-2c2528f2bc68          2.0        Jump

# %%
june.tail()
# Out:
#          pubdatetime   latitude  longitude                sumdid  chargelevel  \
# 28046090         NaT  36.125567 -86.776982  PoweredZYNSVOII2QSLD        100.0
# 28046091         NaT  36.121717 -86.775207  PoweredXOPAIWGL7SF62         93.0
# 28046092         NaT  36.127046 -86.777262  PoweredBYKFOWELGPKH6         61.0
# 28046093         NaT  36.123775 -86.790115  PoweredIAAQ7WODYXON7         35.0
# 28046094         NaT  36.121735 -86.775148  Powered3HJPPUNVYGL45         96.0
#
#          companyname
# 28046090        Lime
# 28046091        Lime
# 28046092        Lime
# 28046093        Lime
# 28046094        Lime

# %%
july = pd.read_pickle('../data/july.pkl')
july.head()
# Out:
#               pubdatetime   latitude  longitude         sumdid  chargelevel  \
# 0 2019-07-01 00:00:33.550  36.156678 -86.809004  Powered635135         22.0
# 1 2019-07-01 00:00:34.973  36.145674 -86.794138  Powered790946         33.0
# 2 2019-07-01 00:00:41.183  36.179319 -86.751538  Powered570380         76.0
# 3 2019-07-01 00:00:41.620  36.152111 -86.803821  Powered240631         43.0
# 4 2019-07-01 00:00:45.087  36.149355 -86.797550  Powered970404         52.0
#
#   companyname
# 0        Lyft
# 1        Lyft
# 2        Lyft
# 3        Lyft
# 4        Lyft

# %%
july.tail()
# Out:
#                  pubdatetime   latitude  longitude  \
# 25075440 2019-07-31 23:59:57  36.162420 -86.779314
# 25075441 2019-07-31 23:59:57  36.146010 -86.810197
# 25075442 2019-07-31 23:59:57  36.165837 -86.777765
# 25075443 2019-07-31 23:59:57  36.149792 -86.806818
# 25075444 2019-07-31 23:59:57  36.162644 -86.779345
#
#                                                 sumdid  chargelevel  \
# 25075440  Powered-1a8321d0-5c21-04a4-bd7d-7b96ba51f17b       100.00
# 25075441  Powered-bd4ba83b-513f-ed5c-3c51-b4f51e7fdc51       100.00
# 25075442  Powered-cc9c0b7e-2b9e-def9-e48b-1a8a489c4daf        71.68
# 25075443  Powered-55a7ac02-7e17-bb3b-130d-b160d9776405         0.00
# 25075444  Powered-03be23ca-d43b-222f-be54-e44b5b4690df       100.00
#
#          companyname
# 25075440        Bolt
# 25075441        Bolt
# 25075442        Bolt
# 25075443        Bolt
# 25075444        Bolt

# %%
may = pd.read_pickle('../data/may.pkl')
may.head()
# Out:
#               pubdatetime   latitude  longitude        sumdid  chargelevel  \
# 0 2019-05-01 00:01:41.247  36.136822 -86.799877  PoweredLIRL1         93.0
# 1 2019-05-01 00:01:41.247  36.191252 -86.772945  PoweredXWRWC         35.0
# 2 2019-05-01 00:01:41.247  36.144752 -86.806293  PoweredMEJEH         90.0
# 3 2019-05-01 00:01:41.247  36.162056 -86.774688  Powered1A7TC         88.0
# 4 2019-05-01 00:01:41.247  36.150973 -86.783109  Powered2TYEF         98.0
#
#   companyname
# 0        Bird
# 1        Bird
# 2        Bird
# 3        Bird
# 4        Bird

# %%
may.tail()
# Out:
#                  pubdatetime  latitude  longitude  \
# 20292498 2019-05-31 23:59:42   36.1639   -86.7823
# 20292499 2019-05-31 23:59:42   36.1606   -86.7768
# 20292500 2019-05-31 23:59:42   36.1606   -86.7769
# 20292501 2019-05-31 23:59:42   36.1624   -86.7745
# 20292502 2019-05-31 23:59:42   36.1519   -86.7985
#
#                                                sumdid  chargelevel companyname
# 20292498  Poweredbb60ef04-c719-597f-805f-20978964fd8c         49.0        Jump
# 20292499  Powered9f5743ed-7f81-539b-9e37-6503d54445d3         68.0        Jump
# 20292500  Powered5744d1db-3bbe-55e5-9a23-a93828ba54fc         53.0        Jump
# 20292501  Poweredad1d6d3b-162a-5bec-bffd-cac4ac8dee1c         42.0        Jump
# 20292502  Powered8505008e-97c9-5003-8975-2ea6b2634fa0         76.0        Jump

# %% [markdown]
# #Read in csv trip files

# %%
may_trip = pd.read_csv('../data/may_trip.csv')
may_trip.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum         sumdID  \
# 0  2019-05-01 00:00:55.423000        Bird       BRD2134   Powered9EAJL
# 1  2019-05-01 00:03:33.147000        Lyft          LFT5  Powered296631
# 2  2019-05-01 00:05:55.570000        Bird       BRD2168   Powered7S2UU
# 3  2019-05-01 00:05:55.570000        Bird       BRD2166   PoweredZIIVX
# 4  2019-05-01 00:05:55.570000        Bird       BRD2165   PoweredJ7MB3
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0        3.0000     958.00528  2019-05-01 00:00:00  00:00:20.460000
# 1        1.7156    1371.39112  2019-05-01 00:00:00  00:01:50.090000
# 2        3.0000    2296.58800  2019-05-01 00:00:00  00:03:47.363333
# 3        3.0000    1200.78744  2019-05-01 00:00:00  00:04:21.386666
# 4        2.0000     351.04988  2019-05-01 00:00:00  00:04:27.796666
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
june_trip = pd.read_csv('../data/june_trip.csv')
june_trip.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-06-01 00:05:46.817000        Bird       BRD3572  PoweredSPI1T
# 1  2019-06-01 00:05:46.817000        Bird       BRD3571  Powered2I3MS
# 2         2019-06-01 00:09:54      Gotcha          GOT1    Powered327
# 3  2019-06-01 00:10:46.957000        Bird       BRD3610  Powered8U1A6
# 4  2019-06-01 00:10:46.957000        Bird       BRD3612  PoweredSPI1T
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0           4.0    328.084000  2019-06-01 00:00:00  00:02:18.203333
# 1           5.0   4921.260000  2019-06-01 00:00:00  00:02:44.803333
# 2          12.0     12.426575  2019-06-01 00:00:00         00:09:56
# 3           2.0      0.000000  2019-06-01 00:00:00  00:10:31.163333
# 4           5.0    656.168000  2019-06-01 00:00:00  00:07:21.430000
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
july_trip = pd.read_csv('../data/july_trip.csv')
july_trip.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-07-01 00:02:52.213000        Bird       BRD5179  PoweredZSHKJ
# 1  2019-07-01 00:02:52.213000        Bird       BRD5177  Powered22JF6
# 2  2019-07-01 00:02:52.213000        Bird       BRD5176  Powered22JF6
# 3  2019-07-01 00:02:52.213000        Bird       BRD5178  PoweredIB2CC
# 4  2019-07-01 00:02:52.213000        Bird       BRD5180  PoweredW4G7R
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0           2.0           0.0  2019-07-01 00:00:00  00:01:32.290000
# 1           0.0           0.0  2019-07-01 00:00:00  00:02:38.640000
# 2           1.0           0.0  2019-07-01 00:00:00  00:03:04.333333
# 3           1.0           0.0  2019-07-01 00:00:00  00:02:06.963333
# 4           2.0           0.0  2019-07-01 00:00:00  00:01:19.843333
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
may.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20283582 entries, 0 to 20292502
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   chargelevel  float64
#  5   companyname  object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 1.1+ GB

# %%
may_trip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224969 entries, 0 to 224968
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    224969 non-null  object
#  1   companyName     224969 non-null  object
#  2   tripRecordNum   224969 non-null  object
#  3   sumdID          224969 non-null  object
#  4   tripDuration    224969 non-null  float64
#  5   tripDistance    224969 non-null  float64
#  6   startDate       224969 non-null  object
#  7   startTime       224969 non-null  object
#  8   endDate         224969 non-null  object
#  9   endTime         224969 non-null  object
#  10  startLatitude   224969 non-null  float64
#  11  startLongitude  224969 non-null  float64
#  12  endLatitude     224969 non-null  float64
#  13  endLongitude    224969 non-null  float64
#  14  tripRoute       224969 non-null  object
#  15  create_dt       224969 non-null  object
# dtypes: float64(6), object(10)
# ...

# %% [markdown]
# #Check for null values in the month dfs

# %%
may.isnull().sum()
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# chargelevel    283
# companyname      0
# dtype: int64

# %%
june.isnull().sum()
# Out:
# pubdatetime    7751135
# latitude             0
# longitude            0
# sumdid               0
# chargelevel        285
# companyname          0
# dtype: int64

# %%
july.isnull().sum()
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# chargelevel    202
# companyname      0
# dtype: int64

# %% [markdown]
# #Null values only in chargelevel column. No nulls within the trip dfs

# %%
may.companyname.value_counts()
# Out:
# Lime      7111655
# Bird      4334006
# Lyft      3112581
# Jump      2984630
# Spin      1301001
# Gotcha     915314
# Bolt       524395
# Name: companyname, dtype: int64

# %%
june.companyname.value_counts()
# Out:
# Jump      8482893
# Lime      6152504
# Bird      4215302
# Lyft      3084229
# Spin      2507991
# Gotcha    1830453
# Bolt      1764036
# Name: companyname, dtype: int64

# %%
july.companyname.value_counts()
# Out:
# Jump      10367575
# Bird       3702282
# Lime       3233573
# Lyft       2890233
# Gotcha     1933513
# Spin       1750581
# Bolt       1188767
# Name: companyname, dtype: int64

# %% [markdown]
# #Rides went up in July, especially for Jump which climbed from 3rd place up to 1st. More tourists maybe?

# %% [markdown]
# #Attempt to append dataframes into 1, did not work.

# %%
append = may_trip.append(june_trip)
append.head(1)
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-05-01 00:00:55.423000        Bird       BRD2134  Powered9EAJL
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0           3.0     958.00528  2019-05-01 00:00:00  00:00:20.460000
#
#                endDate          endTime  startLatitude  startLongitude  \
# 0  2019-05-01 00:00:00  00:02:52.346666        36.1571        -86.8036
#
#    endLatitude  endLongitude  \
# 0      36.1566      -86.8067
#
#                                            tripRoute  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...
#
#                     create_dt
# 0  2019-05-02 05:30:23.780000

# %%
append.tail()
# Out:
#                pubTimeStamp companyName tripRecordNum  \
# 205622  2019-07-01 19:58:07        JUMP         JMP56
# 205623  2019-07-01 19:58:07        JUMP         JMP53
# 205624  2019-07-01 19:58:07        JUMP         JMP52
# 205625  2019-07-01 19:58:07        JUMP         JMP54
# 205626  2019-07-01 19:58:07        JUMP         JMP50
#
#                                              sumdID  tripDuration  \
# 205622  Powered2c1eeca5-26f4-5283-bbcd-5f46b19b7681        1440.0
# 205623  Poweredac7200ea-c5a4-5362-94a8-03e4d2255104        1440.0
# 205624  Powered3f96a82d-9641-58b6-b6db-b80f746a24cd        1440.0
# 205625  Poweredc2d0a425-86dd-5664-a036-d770559391bb        1440.0
# 205626  Powered1b56f557-adce-5c68-a98b-ab1ef41c7dcc        1440.0
#
#         tripDistance            startDate startTime              endDate  \
# 205622       40708.8  2019-06-30 00:00:00  02:16:21  2019-07-01 00:00:00
# 205623       36854.4  2019-06-29 00:00:00  21:46:34  2019-07-01 00:00:00
# ...

# %%
trip = append.append(july_trip)

# %% [markdown]
# #Was able to append all the trip dfs into one df called trip
