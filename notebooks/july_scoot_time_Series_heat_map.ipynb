# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import folium
import datetime
import pickle

# %%
# Import the file as a Pandas DataFrame
fp = '../data/july.csv'
july = pd.read_csv(fp)
july.head(10)

# %%
company_dict = {'Bird':0, 'Lyft': 1, 'Gotcha': 2, 'Lime': 3, 'Spin': 4, 'Jump': 5, 'Bolt': 6}
july.companyname = july.companyname.replace(company_dict)
july.head(10)
# Out:
#                   pubdatetime   latitude  longitude         sumdid sumdtype  \
# 0  2019-07-01 00:00:33.550000  36.156678 -86.809004  Powered635135  Powered
# 1  2019-07-01 00:00:34.973000  36.145674 -86.794138  Powered790946  Powered
# 2  2019-07-01 00:00:41.183000  36.179319 -86.751538  Powered570380  Powered
# 3  2019-07-01 00:00:41.620000  36.152111 -86.803821  Powered240631  Powered
# 4  2019-07-01 00:00:45.087000  36.149355 -86.797550  Powered970404  Powered
# 5  2019-07-01 00:00:46.847000  36.168153 -86.777374  Powered912425  Powered
# 6  2019-07-01 00:00:50.500000  36.143266 -86.809886  Powered667919  Powered
# 7  2019-07-01 00:00:50.520000  36.177355 -86.750667  Powered523737  Powered
# 8  2019-07-01 00:00:53.273000  36.158546 -86.774062  Powered689152  Powered
# 9  2019-07-01 00:00:56.293000  36.177708 -86.750043  Powered211807  Powered
#
#    chargelevel sumdgroup  costpermin  companyname
# 0         22.0   scooter        0.15            1
# 1         33.0   scooter        0.15            1
# 2         76.0   scooter        0.15            1
# 3         43.0   scooter        0.15            1
# 4         52.0   scooter        0.15            1
# 5         80.0   scooter        0.15            1
# 6         60.0   scooter        0.15            1
# 7         85.0   scooter        0.15            1
# 8         72.0   scooter        0.15            1
# 9         99.0   scooter        0.15            1

# %%
july.pubdatetime = pd.to_datetime(july['pubdatetime'])

# %%
july.to_pickle("../data/july.pkl")

# %%
july_scooters = july[['pubdatetime', 'latitude', 'longitude', 'sumdid', 'chargelevel', 'companyname']]

# %%
july_scooters.iloc[6]
# Out:
# pubdatetime    2019-07-01 00:00:50.500000
# latitude                        36.143266
# longitude                      -86.809886
# sumdid                      Powered667919
# chargelevel                          60.0
# companyname                             1
# Name: 6, dtype: object

# %%
july_scooters = july_scooters.set_index('pubdatetime')

# %%
july_scooters.head()
# Out:
#                           latitude  longitude         sumdid  chargelevel  \
# pubdatetime
# 2019-07-01 00:00:33.550  36.156678 -86.809004  Powered635135         22.0
# 2019-07-01 00:00:34.973  36.145674 -86.794138  Powered790946         33.0
# 2019-07-01 00:00:41.183  36.179319 -86.751538  Powered570380         76.0
# 2019-07-01 00:00:41.620  36.152111 -86.803821  Powered240631         43.0
# 2019-07-01 00:00:45.087  36.149355 -86.797550  Powered970404         52.0
#
#                          companyname
# pubdatetime
# 2019-07-01 00:00:33.550            1
# 2019-07-01 00:00:34.973            1
# 2019-07-01 00:00:41.183            1
# 2019-07-01 00:00:41.620            1
# 2019-07-01 00:00:45.087            1

# %%
##july 1 was a monday
july_1_scooters = july_scooters[july_scooters['pubdatetime']<='2019-07-02 00:00:00.000']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pubdatetime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3116/3019052364.py in <module>
#       1 ##july 1 was a monday
# ----> 2 july_1_scooters = july_scooters[july_scooters['pubdatetime']<='2019-07-02 00:00:00.000']
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'pubdatetime'

# %%
# Create an empty list
df_hour_list = []

# Create a series with the different hours of the day
hours = pd.Series(july_scooters.index.hour.unique().sort_values())

# Create a list of points for each hour of the day
def create_list(hour):
    df_hour_list.append(july_scooters.loc[july_scooters.index.hour == hour,
                                ['latitude',
                                 'longitude']].
                        groupby(['latitude', 
                                 'longitude']).sum().reset_index().values.tolist())
hours.apply(create_list);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3116/294737211.py in <module>
#      12                         groupby(['latitude',
#      13                                  'longitude']).sum().reset_index().values.tolist())
# ---> 14 hours.apply(create_list);
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_3116/294737211.py in create_list(hour)
#       7 # Create a list of points for each hour of the day
#       8 def create_list(hour):
# ----> 9     df_hour_list.append(july_scooters.loc[july_scooters.index.hour == hour,
#      10                                 ['latitude',
#      11                                  'longitude']].
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\indexes\extension.py in fget(self)
#      79
#      80             def fget(self):
# ---> 81                 result = getattr(self._data, name)
#      82                 if wrap:
#      83                     if isinstance(result, type(self._data)):
#
# ~\anaconda3\envs\geo_env\lib\site-packages\pandas\core\arrays\datetimes.py in f(self)
#     137
#     138         else:
# --> 139             result = fields.get_date_field(values, field)
#     140             result = self._maybe_mask_results(
#     141                 result, fill_value=None, convert="float64"
#
# KeyboardInterrupt:
