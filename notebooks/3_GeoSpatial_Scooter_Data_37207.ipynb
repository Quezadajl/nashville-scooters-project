# %%
from shapely.geometry import Point # Use in geospatial environment
import pandas as pd
import geopandas as gpd # Use in geospatial environment
import matplotlib.pyplot as plt
import folium #Use in geospatial environment
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
zipcodes = gpd.read_file('../data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head( )
# Out:
# epsg:4326
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37115        1    MADISON  178783.02488886821  596553400.57885742
# 1  37203       33  NASHVILLE  93532.890729543782  120334624.37817383
# 2  37204        9  NASHVILLE  93180.292250425613  200664795.51708984
# 3  37064       18   FRANKLIN  28995.828320601937  46969608.005737305
# 4  37246       57  NASHVILLE  2247.4521491892065  315078.17651367187
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68725 36.31821, -86.68722 ...
# 1  MULTIPOLYGON (((-86.78734 36.16688, -86.78711 ...
# 2  MULTIPOLYGON (((-86.77914 36.13424, -86.77923 ...
# 3  MULTIPOLYGON (((-87.02197 36.01200, -87.02140 ...
# 4  MULTIPOLYGON (((-86.79052 36.15846, -86.79107 ...

# %%
zipcodes.loc[0,'geometry']

# %%
zipcodes.plot();

# %%
#geopandas handles legend styling if you pass a dict of keywords

leg_kwds = {'title': 'Zipcodes', 'loc': 'upper left', 
            'bbox_to_anchor': (1, 1.03), 'ncol': 3}

zipcodes.plot(column = 'zip', figsize=(10, 10),
              edgecolor = 'black',
              legend = True, legend_kwds = leg_kwds, 
              cmap = 'Set3')
plt.show()

# %%
may_trips_pkl = pd.read_pickle('../data/may_trips.pkl')
print(may_trips_pkl.shape)
may_trips_pkl.head()
# Out:
# (224969, 10)
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
# 3 2019-05-01 00:05:55.570       BRD2166
# 4 2019-05-01 00:05:55.570       BRD2165
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
# 3  [[36.149741,-86.779344],[36.149741,-86.779327]...   PoweredZIIVX
# 4  [[36.177699,-86.786477],[36.177711,-86.786469]...   PoweredJ7MB3
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
# 3        3.0000    1200.78744       36.14940     36.15310       -86.77950
# 4        2.0000     351.04988       36.17780     36.17740       -86.78660
#
#    endLongitude
# 0     -86.80670
# 1     -86.77689
# 2     -86.78680
# 3     -86.77960
# 4     -86.78760

# %%
may_trips_pkl.loc[0].tripRoute
# Out:
# '[[36.157235,-86.803612],[36.157235,-86.80362],[36.157226,-86.803642],[36.157226,-86.803665],[36.157226,-86.803665],[36.157226,-86.803665],[36.157218,-86.803734],[36.157218,-86.803734],[36.157218,-86.803734],[36.157218,-86.803734],[36.157206,-86.803872],[36.157206,-86.803872],[36.157191,-86.803986],[36.157191,-86.803986],[36.157191,-86.803986],[36.157143,-86.804184],[36.157143,-86.804184],[36.157143,-86.804184],[36.157081,-86.804406],[36.157081,-86.804406],[36.157081,-86.804406],[36.157081,-86.804406],[36.157043,-86.804642],[36.157001,-86.80484],[36.157001,-86.80484],[36.156945,-86.805069],[36.156945,-86.805069],[36.156945,-86.805069],[36.156913,-86.805267],[36.156913,-86.805267],[36.156856,-86.805489],[36.156856,-86.805489],[36.156913,-86.805267],[36.156856,-86.805489],[36.156856,-86.805489],[36.156821,-86.805696],[36.156821,-86.805696],[36.1568,-86.805817],[36.1568,-86.805817],[36.1568,-86.805817],[36.156746,-86.806001],[36.156746,-86.806001],[36.156746,-86.806001],[36.156688,-86.806206],[36.156688,-86.806206],[36.156688,-86.806206],[36.156688,-86.806206],[36.156688,-86.806206],[36.156665,-86.806404],[36.156665,-86.806404],[36.156665,-86.806404],[36.156646,-86.806519],[36.156646,-86.806519],[36.156623,-86.806694],[36.156623,-86.806694],[36.156623,-86.806694],[36.156623,-86.806694],[36.156623,-86.806694],[36.15657,-86.806915],[36.15657,-86.806915],[36.15651,-86.807144],[36.15651,-86.807144],[36.15651,-86.807144],[36.15651,-86.807144],[36.15651,-86.807144],[36.156463,-86.807289],[36.156463,-86.807289],[36.156463,-86.807289],[36.156463,-86.807289],[36.156403,-86.807602],[36.156403,-86.807602],[36.15636,-86.807847],[36.15636,-86.807847],[36.156315,-86.808014],[36.156315,-86.808014],[36.15625,-86.808244],[36.15625,-86.808244],[36.156205,-86.808419],[36.156205,-86.808419],[36.156205,-86.808419],[36.156158,-86.808655],[36.156158,-86.808655],[36.156158,-86.808655],[36.156158,-86.808655],[36.156158,-86.808655],[36.156113,-86.808899],[36.15607,-86.809067],[36.15607,-86.809067],[36.15607,-86.809067],[36.156001,-86.809304],[36.156001,-86.809304],[36.156001,-86.809304],[36.155941,-86.809517],[36.156001,-86.809304],[36.155941,-86.809517],[36.155941,-86.809517],[36.155941,-86.809517],[36.155941,-86.809517],[36.155918,-86.809671],[36.155918,-86.809671],[36.155918,-86.809671]]'

# %%
may_trips_pkl['geometry'] = may_trips_pkl.apply(lambda x: Point((x.startLongitude, x.startLatitude)), 
                                        axis=1)
may_trips_pkl.head(3)
# Out:
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
#
#    endLongitude                    geometry
# 0     -86.80670    POINT (-86.8036 36.1571)
# 1     -86.77689  POINT (-86.77896 36.15797)
# 2     -86.78680    POINT (-86.7818 36.1547)

# %%
zipcodes.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
may_scooter_geo = gpd.GeoDataFrame(may_trips_pkl, 
                           crs = zipcodes.crs, 
                           geometry = may_trips_pkl['geometry'])

# %%
zipcodes = zipcodes[['zip', 'po_name', 'geometry']]

# %%
stops_by_zip = gpd.sjoin(may_scooter_geo, zipcodes, op = 'within')

# %%
stops_by_zip.head()
# Out:
#              pubTimeStamp tripRecordNum  \
# 0 2019-05-01 00:00:55.423       BRD2134
# 1 2019-05-01 00:03:33.147          LFT5
# 2 2019-05-01 00:05:55.570       BRD2168
# 3 2019-05-01 00:05:55.570       BRD2166
# 5 2019-05-01 00:05:55.570       BRD2167
#
#                                            tripRoute         sumdID  \
# 0  [[36.157235,-86.803612],[36.157235,-86.80362],...   Powered9EAJL
# 1  [[36.15797,-86.77896],[36.15795,-86.77873],[36...  Powered296631
# 2     [[36.155068,-86.782124],[36.156597,-86.78675]]   Powered7S2UU
# 3  [[36.149741,-86.779344],[36.149741,-86.779327]...   PoweredZIIVX
# 5  [[36.154368,-86.785909],[36.151689,-86.784331]...   PoweredEJF1K
#
#    tripDuration  tripDistance  startLatitude  endLatitude  startLongitude  \
# 0        3.0000     958.00528       36.15710     36.15660       -86.80360
# 1        1.7156    1371.39112       36.15797     36.16054       -86.77896
# 2        3.0000    2296.58800       36.15470     36.15650       -86.78180
# 3        3.0000    1200.78744       36.14940     36.15310       -86.77950
# 5        3.0000     984.25200       36.15440     36.15150       -86.78620
#
#    endLongitude                    geometry  index_right    zip    po_name
# 0     -86.80670  POINT (-86.80360 36.15710)            1  37203  NASHVILLE
# 1     -86.77689  POINT (-86.77896 36.15797)            1  37203  NASHVILLE
# 2     -86.78680  POINT (-86.78180 36.15470)            1  37203  NASHVILLE
# 3     -86.77960  POINT (-86.77950 36.14940)            1  37203  NASHVILLE
# 5     -86.78440  POINT (-86.78620 36.15440)            1  37203  NASHVILLE

# %%
stops_by_zip['zip'].value_counts()
# Out:
# 37203    97397
# 37201    39847
# 37219    17858
# 37212    17020
# 37204    15713
# 37206     8866
# 37208     8725
# 37213     8710
# 37210     4870
# 37240     1605
# 37232     1379
# 37207     1086
# 37209      702
# 37215      330
# 37228      243
# 37216      206
# 37205      185
# 37246       99
# 37211       42
# 37217       41
# 37214       15
# 37013       15
# 37218        5
# 37221        5
# 37115        3
# 37138        1
# 37220        1
# Name: zip, dtype: int64

# %%
stops_in_37203 = stops_by_zip.loc[stops_by_zip['zip'] == '37203']
stops_in_37203.shape
# Out:
# (97397, 14)

# %%
polygon37203 = zipcodes.loc[zipcodes['zip'] == '37203']
polygon37203.shape
# Out:
# (1, 3)

# %%
#fig, ax = matplotlib.subplots()
ax = polygon37203.plot(figsize = (8, 10), color = 'lightgreen')
stops_in_37203.plot( ax = ax, column = 'tripRoute');
plt.show();

# %%
polygon37203.geometry.centroid
# Out:
# C:\Users\Joselit\AppData\Local\Temp/ipykernel_3228/651956959.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   polygon37203.geometry.centroid
# 1    POINT (-86.78898 36.14857)
# dtype: geometry

# %%
#find the center of the larger (more southern) polygon and look at it
center = polygon37203.geometry.centroid[1]
print(center)
# Out:
# POINT (-86.7889841001608 36.14857447556778)
# C:\Users\Joselit\AppData\Local\Temp/ipykernel_3228/3256755390.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center = polygon37203.geometry.centroid[1]

# %%
# reverse the order when constructing the array for folium location
area_center = [center.y, center.x]

# check the order of area_center, the location for our folium map
print(area_center)
# Out:
# [36.148574475567784, -86.7889841001608]

# %%
#create our map of Nashville Zip Code 37203 and show it
map_37203 = folium.Map(location =  area_center, zoom_start = 12)
map_37203
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e3f2f7634d0e4fbc96e975a2be393f11%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e3f2f7634d0e4fbc96e975a2be393f11%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e3f2f7634d0e4fbc96e975a2be393f11%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e3f2f7634d0e4fbc96e975a2be393f11%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B36.148574475567784%2C%20-86.7889841001608%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
i = 0
for row_index, row_values in stops_in_37203.iterrows():
    if i <3: 
        print('index is', row_index)
        print('values are:')
        print(' ')
        print(row_values)
        print('------------------------- ')
        i+=1
# Out:
# index is 0
# values are:
#
# pubTimeStamp                             2019-05-01 00:00:55.423000
# tripRecordNum                                               BRD2134
# tripRoute         [[36.157235,-86.803612],[36.157235,-86.80362],...
# sumdID                                                 Powered9EAJL
# tripDuration                                                    3.0
# tripDistance                                              958.00528
# startLatitude                                               36.1571
# endLatitude                                                 36.1566
# startLongitude                                             -86.8036
# endLongitude                                               -86.8067
# geometry                                   POINT (-86.8036 36.1571)
# index_right                                                       1
# zip                                                           37203
# po_name                                                   NASHVILLE
# Name: 0, dtype: object
# -------------------------
# index is 1
# values are:
#
# pubTimeStamp                             2019-05-01 00:03:33.147000
# tripRecordNum                                                  LFT5
# tripRoute         [[36.15797,-86.77896],[36.15795,-86.77873],[36...
# sumdID                                                Powered296631
# tripDuration                                                 1.7156
# tripDistance                                             1371.39112
# startLatitude                                              36.15797
# endLatitude                                                36.16054
# startLongitude                                            -86.77896
# endLongitude                                              -86.77689
# geometry                                 POINT (-86.77896 36.15797)
# index_right                                                       1
# zip                                                           37203
# po_name                                                   NASHVILLE
# Name: 1, dtype: object
# -------------------------
# index is 2
# values are:
#
# pubTimeStamp                          2019-05-01 00:05:55.570000
# tripRecordNum                                            BRD2168
# tripRoute         [[36.155068,-86.782124],[36.156597,-86.78675]]
# sumdID                                              Powered7S2UU
# tripDuration                                                 3.0
# tripDistance                                            2296.588
# startLatitude                                            36.1547
# endLatitude                                              36.1565
# startLongitude                                          -86.7818
# endLongitude                                            -86.7868
# geometry                                POINT (-86.7818 36.1547)
# index_right                                                    1
# zip                                                        37203
# po_name                                                NASHVILLE
# Name: 2, dtype: object
# -------------------------

# %%
#draw our zip code area: 37203
map_37203 = folium.Map(location =  area_center, zoom_start = 12)

folium.GeoJson(polygon37203).add_to(map_37203)

#iterate through stops_in_37203 to create locations and markers 
#for each bus stop
#remember for Folium locations, lat is listed first!!

for row_index, row_values in stops_in_37203.iterrows():
    loc = [row_values['startLatitude'], row_values['startLongitude']]
    pop = str(row_values['tripRoute'])
    icon=folium.Icon(color="blue",icon="bicycle", prefix='fa')
    
    marker = folium.Marker(
        location = loc, 
        popup = pop, icon = icon) 

    marker.add_to(map_37203)
#map_37215.save('../maps/map37207.html')

#display our map
map_37203
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3228/1208890815.py in <module>
#      21
#      22 #display our map
# ---> 23 map_37203
#
# ~\anaconda3\envs\geospatial\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~\anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\envs\geospatial\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\envs\geospatial\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\envs\geospatial\lib\site-packages\folium\folium.py in _repr_html_(self, **kwargs)
#     291             self._parent = None
#     292         else:
# --> 293             out = self._parent._repr_html_(**kwargs)
#     294         return out
#     295
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in _repr_html_(self, **kwargs)
#     329
#     330         """
# --> 331         html = urllib.parse.quote(self.render(**kwargs))
#     332         onload = (
#     333             'this.contentDocument.open();'
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     317         """Renders the HTML representation of the element."""
#     318         for name, child in self._children.items():
# --> 319             child.render(**kwargs)
#     320         return self._template.render(this=self, kwargs=kwargs)
#     321
#
# ~\anaconda3\envs\geospatial\lib\site-packages\folium\folium.py in render(self, **kwargs)
#     368             '</style>'), name='map_style')
#     369
# --> 370         super(Map, self).render(**kwargs)
#     371
#     372     def fit_bounds(self, bounds, padding_top_left=None,
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     641
#     642         for name, element in self._children.items():
# --> 643             element.render(**kwargs)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     641
#     642         for name, element in self._children.items():
# --> 643             element.render(**kwargs)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in render(self, **kwargs)
#     637         script = self._template.module.__dict__.get('script', None)
#     638         if script is not None:
# --> 639             figure.script.add_child(Element(script(self, kwargs)),
#     640                                     name=self.get_name())
#     641
#
# ~\anaconda3\envs\geospatial\lib\site-packages\branca\element.py in __init__(self, template, template_name)
#      57
#      58         if template is not None:
# ---> 59             self._template = Template(template)
#      60         elif template_name is not None:
#      61             self._template = ENV.get_template(template_name)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in __new__(cls, source, block_start_string, block_end_string, variable_start_string, variable_end_string, comment_start_string, comment_end_string, line_statement_prefix, line_comment_prefix, trim_blocks, lstrip_blocks, newline_sequence, keep_trailing_newline, extensions, optimized, undefined, finalize, autoescape, enable_async)
#    1206             enable_async,
#    1207         )
# -> 1208         return env.from_string(source, template_class=cls)
#    1209
#    1210     @classmethod
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in from_string(self, source, globals, template_class)
#    1090         gs = self.make_globals(globals)
#    1091         cls = template_class or self.template_class
# -> 1092         return cls.from_code(self, self.compile(source), gs, None)
#    1093
#    1094     def make_globals(
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in compile(self, source, name, filename, raw, defer_init)
#     747             if isinstance(source, str):
#     748                 source_hint = source
# --> 749                 source = self._parse(source, name, filename)
#     750             source = self._generate(source, name, filename, defer_init=defer_init)
#     751             if raw:
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in _parse(self, source, name, filename)
#     604     ) -> nodes.Template:
#     605         """Internal parsing function used by `parse` and `compile`."""
# --> 606         return Parser(self, source, name, filename).parse()
#     607
#     608     def lex(
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\parser.py in __init__(self, environment, source, name, filename, state)
#      58     ) -> None:
#      59         self.environment = environment
# ---> 60         self.stream = environment._tokenize(source, name, filename, state)
#      61         self.name = name
#      62         self.filename = filename
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in _tokenize(self, source, name, filename, state)
#     654         """
#     655         source = self.preprocess(source, name, filename)
# --> 656         stream = self.lexer.tokenize(source, name, filename, state)
#     657
#     658         for ext in self.iter_extensions():
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\environment.py in lexer(self)
#     442     def lexer(self) -> Lexer:
#     443         """The lexer for this environment."""
# --> 444         return get_lexer(self)
#     445
#     446     def iter_extensions(self) -> t.Iterator["Extension"]:
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\lexer.py in get_lexer(environment)
#     440         environment.keep_trailing_newline,
#     441     )
# --> 442     lexer = _lexer_cache.get(key)
#     443
#     444     if lexer is None:
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\utils.py in get(self, key, default)
#     542         """Return an item from the cache dict or `default`"""
#     543         try:
# --> 544             return self[key]
#     545         except KeyError:
#     546             return default
#
# ~\anaconda3\envs\geospatial\lib\site-packages\jinja2\utils.py in __getitem__(self, key)
#     593                 self._append(key)
#     594
# --> 595             return rv
#     596
#     597     def __setitem__(self, key: t.Any, value: t.Any) -> None:
#
# KeyboardInterrupt:
